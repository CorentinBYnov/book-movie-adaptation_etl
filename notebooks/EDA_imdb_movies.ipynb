# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/imdb_movie_dataset.csv")
df.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
print(df.isna().sum())
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#      Rank                    Title                    Genre  \
# 7       8                 Mindhorn                   Comedy
# 22     23           Hounds of Love       Crime,Drama,Horror
# 25     26          Paris pieds nus                   Comedy
# 26     27  Bahubali: The Beginning   Action,Adventure,Drama
# 27     28               Dead Awake          Horror,Thriller
# ..    ...                      ...                      ...
# 988   989                  Martyrs                   Horror
# 989   990                    Selma  Biography,Drama,History
# 992   993     Take Me Home Tonight     Comedy,Drama,Romance
# 995   996     Secret in Their Eyes      Crime,Drama,Mystery
# 998   999             Search Party         Adventure,Comedy
#
#                                            Description        Director  \
# 7    A has-been actor best known for playing the ti...      Sean Foley
# 22   A cold-blooded predatory couple while cruising...       Ben Young
# ...

# %%
print(df.Year.min(), df.Year.max())
# Out:
# 2006 2016

# %%
print(df.Rank.duplicated().any())
# Out:
# False

# %%
print(df.shape)
# Out:
# (1000, 12)

# %%
matches = df.Title.str.contains(r'lost city', case=False)
df[matches]
# Out:
#    Rank               Title                       Genre  \
# 8     9  The Lost City of Z  Action,Adventure,Biography
#
#                                          Description    Director  \
# 8  A true-life drama, centering on British explor...  James Gray
#
#                                               Actors  Year  Runtime (Minutes)  \
# 8  Charlie Hunnam, Robert Pattinson, Sienna Mille...  2016                141
#
#    Rating  Votes  Revenue (Millions)  Metascore
# 8     7.1   7188                8.01       78.0

# %%
matches = df.Title.str.contains(r'harry potter', case=False)
df[matches]
# Out:
#      Rank                                         Title  \
# 114   115  Harry Potter and the Deathly Hallows: Part 2
# 314   315     Harry Potter and the Order of the Phoenix
# 418   419  Harry Potter and the Deathly Hallows: Part 1
# 473   474        Harry Potter and the Half-Blood Prince
#
#                         Genre  \
# 114   Adventure,Drama,Fantasy
# 314  Adventure,Family,Fantasy
# 418  Adventure,Family,Fantasy
# 473  Adventure,Family,Fantasy
#
#                                            Description     Director  \
# 114  Harry, Ron and Hermione search for Voldemort's...  David Yates
# 314  With their warning about Lord Voldemort's retu...  David Yates
# 418  As Harry races against time and evil to destro...  David Yates
# 473  As Harry Potter begins his sixth year at Hogwa...  David Yates
#
#                                                 Actors  Year  \
# 114  Daniel Radcliffe, Emma Watson, Rupert Grint, M...  2011
# ...

# %%
matches = df.Title.str.contains(r'hobbit', case=False)
df[matches]
# Out:
#      Rank                                      Title              Genre  \
# 271   272          The Hobbit: An Unexpected Journey  Adventure,Fantasy
# 313   314  The Hobbit: The Battle of the Five Armies  Adventure,Fantasy
# 518   519        The Hobbit: The Desolation of Smaug  Adventure,Fantasy
#
#                                            Description       Director  \
# 271  A reluctant hobbit, Bilbo Baggins, sets out to...  Peter Jackson
# 313  Bilbo and Company are forced to engage in a wa...  Peter Jackson
# 518  The dwarves, along with Bilbo Baggins and Gand...  Peter Jackson
#
#                                                 Actors  Year  \
# 271  Martin Freeman, Ian McKellen, Richard Armitage...  2012
# 313  Ian McKellen, Martin Freeman, Richard Armitage...  2014
# 518  Ian McKellen, Martin Freeman, Richard Armitage...  2013
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 271                169     7.9  668651              303.00       58.0
# ...
