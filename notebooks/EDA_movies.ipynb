# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/movies.csv")
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
print(df.isna().sum())
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
print(df.budget.isna().sum() / df.shape[0] * 100)
# Out:
# 28.31246739697444

# %%
matches = df.name.str.contains(r'zodiac', case=False)
df[matches]
# Out:
#         name rating  genre  year                       released  score  \
# 5048  Zodiac      R  Crime  2007  March 2, 2007 (United States)    7.7
#
#          votes       director            writer             star  \
# 5048  486000.0  David Fincher  James Vanderbilt  Jake Gyllenhaal
#
#             country      budget       gross             company  runtime
# 5048  United States  65000000.0  84785914.0  Paramount Pictures    157.0

# %%
matches = df.name.str.contains(r'harry potter', case=False)
df[matches]
# Out:
#                                               name rating      genre  year  \
# 3843         Harry Potter and the Sorcerer's Stone     PG  Adventure  2001
# 4047       Harry Potter and the Chamber of Secrets     PG  Adventure  2002
# 4448      Harry Potter and the Prisoner of Azkaban     PG  Adventure  2004
# 4643           Harry Potter and the Goblet of Fire  PG-13  Adventure  2005
# 5051     Harry Potter and the Order of the Phoenix  PG-13     Action  2007
# 5451        Harry Potter and the Half-Blood Prince     PG     Action  2009
# 5652  Harry Potter and the Deathly Hallows: Part 1  PG-13  Adventure  2010
# 5845  Harry Potter and the Deathly Hallows: Part 2  PG-13  Adventure  2011
#
#                                released  score     votes        director  \
# 3843  November 16, 2001 (United States)    7.6  685000.0  Chris Columbus
# 4047  November 15, 2002 (United States)    7.4  572000.0  Chris Columbus
# ...

# %%
matches = df.name.str.contains(r'the danish girl', case=False)
df[matches]
# Out:
#                  name rating      genre  year  \
# 6694  The Danish Girl      R  Biography  2015
#
#                               released  score     votes    director  \
# 6694  January 22, 2016 (United States)    7.1  170000.0  Tom Hooper
#
#              writer            star         country      budget       gross  \
# 6694  Lucinda Coxon  Eddie Redmayne  United Kingdom  15000000.0  64191523.0
#
#                   company  runtime
# 6694  Working Title Films    119.0

# %%
matches = df.name.str.contains(r'hobbit', case=False)
df[matches]
# Out:
#                                            name rating      genre  year  \
# 6045          The Hobbit: An Unexpected Journey  PG-13  Adventure  2012
# 6253        The Hobbit: The Desolation of Smaug  PG-13  Adventure  2013
# 6455  The Hobbit: The Battle of the Five Armies  PG-13  Adventure  2014
#
#                                released  score     votes       director  \
# 6045  December 14, 2012 (United States)    7.8  773000.0  Peter Jackson
# 6253  December 13, 2013 (United States)    7.8  615000.0  Peter Jackson
# 6455  December 17, 2014 (United States)    7.4  487000.0  Peter Jackson
#
#           writer            star      country       budget         gross  \
# 6045  Fran Walsh  Martin Freeman  New Zealand  180000000.0  1.017004e+09
# 6253  Fran Walsh    Ian McKellen  New Zealand  225000000.0  9.590075e+08
# 6455  Fran Walsh    Ian McKellen  New Zealand  250000000.0  9.621829e+08
#
#                         company  runtime
# 6045  Metro-Goldwyn-Mayer (MGM)    169.0
# ...

# %%
print((df.gross[6455] - df.budget[6455]) / df.budget[6455] * 100)
# Out:
# 284.873146

# %%
matches = df.name.str.contains(r'prometheus', case=False)
df[matches]
# Out:
#             name rating      genre  year                      released  score  \
# 6051  Prometheus      R  Adventure  2012  June 8, 2012 (United States)    7.0
#
#          votes      director       writer          star        country  \
# 6051  578000.0  Ridley Scott  Jon Spaihts  Noomi Rapace  United States
#
#            budget        gross                company  runtime
# 6051  130000000.0  403354469.0  Twentieth Century Fox    124.0

# %%
print((df.gross[6051] - df.budget[6051]) / df.budget[6051] * 100)
# Out:
# 210.27266846153844
